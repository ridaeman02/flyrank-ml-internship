# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ridaeman02/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing the **Content Refresh and Traffic Decline** lane. Based on my first look at the data, finding out which pages are losing traffic is a major business win. Automating this list will help us separate real traffic loss from normal daily drops.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Quick check to ensure the file path works
import os
print("Starter data exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Starter data exists: False

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# * **The Decision:** Deciding which exact pages need a content update or rewrite, and which ones should be left alone.
# * **The Action:** A writer or SEO editor updates the old facts on the page, fixes mismatched content, or adds better internal links.
# * **The Cost of a Wrong Call:** If we flag a healthy page as shrinking (False Alarm), we waste time and money rewriting something that is fine. If we miss a truly shrinking page, we lose traffic and revenue to our competitors forever.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 2 complete - Framework defined

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# I loaded the starter data to see the real metrics. Out of 30,000 total pages, 6,634 pages are actively losing traffic. This means roughly 22.1% of the site's content is shrinking, which proves that fixing this lane is worth our time over the next 7 weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Compute 2-3 real supporting numbers
total_rows = len(df)
declining_rows = df["trend_direction"].str.lower().eq("down").sum()
pct_declining = (declining_rows / total_rows) * 100

print(f"Total pages analyzed: {total_rows}")
print(f"Number of declining pages: {declining_rows}")
print(f"Percentage of site declining: {pct_declining:.1f}%")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_966/2939183709.py in <cell line: 0>()
#       4
#       5 # Load the starter dataset
# ----> 6 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       7
#       8 # Compute 2-3 real supporting numbers
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# * **What I can claim:** This model will give decision-support by showing clear patterns and directional trends inside this specific data. It points out pages that look exactly like past pages that lost traffic.
# * **What I cannot claim:** This work will never claim causal proof. It will never claim to predict Google's algorithm or explain how search systems work globally. It only tracks the history of the data we own.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
